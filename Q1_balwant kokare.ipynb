# %%
# Importing libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# here imported dataset
df = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\CDAC-DBDA\module 7\Machine Learning\lab exam\data_1.csv')

# %%
# here we check first 5 records
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# here we check last 5 records
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
# here we check column and row
df.shape
# Out:
# (301, 9)

# %%
# here we check information about datatype an null values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# we use this command for check values of min,max mean,median,mode
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# # Handling Missing Values

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# here we can saw no null values are available in columns as well as rows

# %% [markdown]
# # Cleaning dataset

# %%
df.duplicated().count()
# Out:
# 301

# %%
# here we removed two duplicate columns
df.drop_duplicates()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# Here we found two duplicate row thats why remove from dataset for data cleaning

# %%
# plotting graph for better visulizations
sns.catplot('Selling_Price',data=df)

# %%
# here we are lotting relation betn selling and present price
df.plot.scatter(x='Selling_Price',y='Present_Price')
plt.show()

# %%
# As per we see every year all petrol car and bike are more for selling than diesel and CNG
plt.figure(figsize=(10,10))
sns.countplot('Year',hue='Fuel_Type',data=df)
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# lets here visulize or compare which transmission more price manual or automatic
plt.figure(figsize=(10,10))
sns.catplot(data=df,kind='swarm',x='Transmission',y='Selling_Price',split=True)
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# here Boxplot for checking outlier
sns.boxplot(data=df,x='Selling_Price',y='Seller_Type')
plt.show()

# %%
# here Boxplot for checking outlier year and selling price
sns.boxplot(data=df,x='Year',y='Selling_Price')
plt.show()

# %% [markdown]
# ### dropping car name column as it has many number of unique columns as our dataset is very short

# %%
df.drop('Car_Name',axis=1,inplace=True)
df.head(5)
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
# converting year column into number of years selling car is old
df['curr_Year']=2020
df['Years']=df.curr_Year - df.Year
df.drop(['Years','curr_Year'],axis=1,inplace=True)
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %% [markdown]
# ### getting dummies for categorical columns we can also usedf.replace as unique value are less

# %%
df = pd.get_dummies(df,drop_first=True)
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0  2014           3.35           5.59       27000      0                 0
# 1  2013           4.75           9.54       43000      0                 1
# 2  2017           7.25           9.85        6900      0                 0
# 3  2011           2.85           4.15        5200      0                 0
# 4  2014           4.60           6.87       42450      0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
# plotting pairplot for all dataset
sns.pairplot(data=df)
plt.show()

# %%
#plotting corelation betn datasetcolumn by using heatmap
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # 4.Model building and evaluation

# %% [markdown]
# ### Taking dependent and independent columns into differnt variable

# %%
x=df.drop('Selling_Price',axis=1)
y=df['Selling_Price']

# %%
print(x.shape)
# Out:
# (301, 8)

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
# split dataset training between training and test dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=1)

# %%
# here applying min max scaler for Normalization
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# applying random forest regression model
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.9012612056612193

# %%
y_pred = model1.predict(x_test)

# %%
y_pred
# Out:
# array([16.1351,  5.355 ,  0.7019,  7.6605,  1.141 , 13.8772,  1.486 ,
#         4.4711, 21.644 ,  0.7483, 20.0922,  5.6665, 11.5805,  8.3931,
#         0.396 ,  0.3299, 19.4263, 15.169 , 14.4475, 19.4263, 13.1812,
#        15.527 , 25.558 , 21.43  , 25.4075,  8.7348, 15.6955,  1.089 ,
#         0.2097,  0.716 ,  0.2396,  0.197 ,  9.344 , 28.4765, 28.6565,
#         8.3281,  5.6581,  1.2355,  0.2188,  6.1095, 21.84  , 21.9973,
#         0.2827,  9.6133,  9.5913,  8.3931, 19.1175, 17.6143, 19.4263,
#         2.6965,  6.9476,  0.379 ,  5.0945, 10.0966,  2.5211,  0.1319,
#        28.4765,  0.7452, 16.8683, 15.3185,  0.1971])

# %%
x_test
# Out:
# array([[8.57142857e-01, 1.69252468e-03, 1.69587760e-01, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [8.57142857e-01, 3.69252468e-01, 7.23175998e-02, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [5.71428571e-01, 2.50775740e-01, 4.38537511e-01, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [5.00000000e-01, 1.69252468e-03, 2.51766850e-01, 1.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [6.42857143e-01, 5.10578279e-01, 2.89128453e-01, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [7.85714286e-01, 2.37235543e-01, 3.06804429e-01, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [7.85714286e-01, 2.70803949e-02, 1.84529413e-01, 0.00000000e+00,
# ...

# %% [markdown]
# # 5.Result with error calculation

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
min_samples_split = [2, 5, 10, 15, 100]
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
rf = RandomForestRegressor()
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   2.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   2.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   2.1s
# ...
